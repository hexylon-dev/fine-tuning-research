# %%
import transformers
import torch
from transformers import pipeline

# %%
model = "meta-llama/Meta-Llama-3-8B"
generator = pipeline("text-generation", model=model)
input_text = "Once upon a time"
generated_text = generator(input_text, max_length=100, num_return_sequences=1)
# Out:
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 model = "meta-llama/Meta-Llama-3-8B"
# ----> 2 generator = pipeline("text-generation", model=model)
#       3 input_text = "Once upon a time"
#       4 generated_text = generator(input_text, max_length=100, num_return_sequences=1)
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\pipelines\__init__.py:940, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938 if isinstance(model, str) or framework is None:
#     939     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940     framework, model = infer_framework_load_model(
#     941         model,
#     942         model_classes=model_classes,
#     943         config=config,
#     944         framework=framework,
#     945         task=task,
#     946         **hub_kwargs,
#     947         **model_kwargs,
#     948     )
#     950 model_config = model.config
#     951 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\pipelines\base.py:289, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     283     logger.warning(
#     284         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     285         "Trying to load the model with Tensorflow."
#     286     )
#     288 try:
# --> 289     model = model_class.from_pretrained(model, **kwargs)
#     290     if hasattr(model, "eval"):
#     291         model = model.eval()
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:4264, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4254         load_contexts.append(tp_device)
#    4256     with ContextManagers(load_contexts):
#    4257         (
#    4258             model,
#    4259             missing_keys,
#    4260             unexpected_keys,
#    4261             mismatched_keys,
#    4262             offload_index,
#    4263             error_msgs,
# -> 4264         ) = cls._load_pretrained_model(
#    4265             model,
#    4266             state_dict,
#    4267             loaded_state_dict_keys,  # XXX: rename?
#    4268             resolved_archive_file,
#    4269             pretrained_model_name_or_path,
#    4270             ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4271             sharded_metadata=sharded_metadata,
#    4272             _fast_init=_fast_init,
#    4273             low_cpu_mem_usage=low_cpu_mem_usage,
#    4274             device_map=device_map,
#    4275             offload_folder=offload_folder,
#    4276             offload_state_dict=offload_state_dict,
#    4277             dtype=torch_dtype,
#    4278             hf_quantizer=hf_quantizer,
#    4279             keep_in_fp32_modules=keep_in_fp32_modules,
#    4280             gguf_path=gguf_path,
#    4281             weights_only=weights_only,
#    4282         )
#    4284 # make sure token embedding weights are still tied if needed
#    4285 model.tie_weights()
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:4800, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path, weights_only)
#    4796     if assign_to_params_buffers is None:
#    4797         assign_to_params_buffers = check_support_param_buffer_assignment(
#    4798             model_to_load, state_dict, start_prefix
#    4799         )
# -> 4800     error_msgs += _load_state_dict_into_model(
#    4801         model_to_load, state_dict, start_prefix, assign_to_params_buffers
#    4802     )
#    4804 # force memory release
#    4805 del state_dict
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:724, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix, assign_to_params_buffers)
#     721         if child is not None:
#     722             load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
# --> 724 load(model_to_load, state_dict, prefix=start_prefix, assign_to_params_buffers=assign_to_params_buffers)
#     725 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     726 # it's safe to delete it.
#     727 del state_dict
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:722, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     720 for name, child in module._modules.items():
#     721     if child is not None:
# --> 722         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:722, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     720 for name, child in module._modules.items():
#     721     if child is not None:
# --> 722         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 722 (2 times)]
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:722, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     720 for name, child in module._modules.items():
#     721     if child is not None:
# --> 722         load(child, state_dict, prefix + name + ".", assign_to_params_buffers)
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\transformers\modeling_utils.py:718, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix, assign_to_params_buffers)
#     716                     module._load_from_state_dict(*args)
#     717     else:
# --> 718         module._load_from_state_dict(*args)
#     720 for name, child in module._modules.items():
#     721     if child is not None:
#
# File ~\miniconda3\envs\hugging-face\Lib\site-packages\torch\nn\modules\module.py:2441, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2439             setattr(self, name, input_param)
#    2440         else:
# -> 2441             param.copy_(input_param)
#    2442 except Exception as ex:
#    2443     action = "swapping" if use_swap_tensors else "copying"
#
# KeyboardInterrupt:

# %%
# !huggingface-cli login --token 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
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `dev-2` has been saved to C:\Users\baps\.cache\huggingface\stored_tokens
# Your token has been saved to C:\Users\baps\.cache\huggingface\token
# Login successful.
# The current active token is: `dev-2`
